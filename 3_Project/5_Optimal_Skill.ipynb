# %% [markdown]
# Import Libraries and Data

# %%
# importing libs
import pandas as pd
import matplotlib.pyplot as plt
import ast
import seaborn as sns


# loading local data
df = pd.read_csv("/Users/suegreen/Downloads/projects/data/3_Project/data_jobs.csv")

# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Clean Data

# %%
df_DA_DE = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Germany')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_DE = df_DA_DE.dropna(subset=['salary_year_avg'])

df_DA_DE_exploded = df_DA_DE.explode('job_skills')

df_DA_DE_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#        salary_year_avg job_skills
# 20066          75067.5          r
# 20066          75067.5     python
# 20066          75067.5       java
# 20066          75067.5         c#
# 20066          75067.5        sql

# %% [markdown]
# Calculate Percent of Job Postings that Have Skills

# %%
# using df_DA find the count of skills and also the median salary for each skill
df_DA_skills = df_DA_DE_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_DE)  # Find count of Data Analyst jobs in US with salary info

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

df_DA_skills = df_DA_skills[df_DA_skills['skill_count'] > 0]

df_DA_skills
# Out:
#                skill_count  median_salary  skill_percent
# job_skills
# sql                     24      101500.00      50.000000
# python                  18      111175.00      37.500000
# tableau                 13      100500.00      27.083333
# spark                    7      111175.00      14.583333
# r                        7       75067.50      14.583333
# excel                    7      105650.00      14.583333
# looker                   5       53014.00      10.416667
# power bi                 4       83937.50       8.333333
# go                       4       52014.00       8.333333
# pandas                   4      108412.50       8.333333
# gcp                      3      165000.00       6.250000
# github                   3      199675.00       6.250000
# aws                      3      100500.00       6.250000
# azure                    3       89100.00       6.250000
# matplotlib               3      105650.00       6.250000
# numpy                    2      105650.00       4.166667
# c#                       2       82083.75       4.166667
# sas                      2      105650.00       4.166667
# sap                      2       78007.00       4.166667
# powerpoint               2       83937.50       4.166667
# pyspark                  1      111175.00       2.083333
# atlassian                1      102500.00       2.083333
# react                    1      111175.00       2.083333
# redshift                 1      166419.50       2.083333
# sql server               1       89100.00       2.083333
# terminal                 1      111175.00       2.083333
# sheets                   1       57500.00       2.083333
# no-sql                   1      111175.00       2.083333
# pascal                   1       92000.00       2.083333
# oracle                   1       56700.00       2.083333
# nosql                    1      166419.50       2.083333
# neo4j                    1       89100.00       2.083333
# matlab                   1      111175.00       2.083333
# linux                    1       89100.00       2.083333
# kafka                    1      166419.50       2.083333
# julia                    1       89100.00       2.083333
# javascript               1      111175.00       2.083333
# java                     1       75067.50       2.083333
# git                      1      105000.00       2.083333
# flask                    1      111175.00       2.083333
# elasticsearch            1      111175.00       2.083333
# databricks               1      111175.00       2.083333
# bigquery                 1      166419.50       2.083333
# terraform                1      166419.50       2.083333

# %% [markdown]
# Median Salary vs Percent Skill Demand

# %%
skill_limit = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_limit]

df_DA_skills_high_demand
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                  24       101500.0      50.000000
# python               18       111175.0      37.500000
# tableau              13       100500.0      27.083333
# spark                 7       111175.0      14.583333
# r                     7        75067.5      14.583333
# excel                 7       105650.0      14.583333
# looker                5        53014.0      10.416667
# power bi              4        83937.5       8.333333
# go                    4        52014.0       8.333333
# pandas                4       108412.5       8.333333
# gcp                   3       165000.0       6.250000
# github                3       199675.0       6.250000
# aws                   3       100500.0       6.250000
# azure                 3        89100.0       6.250000
# matplotlib            3       105650.0       6.250000

# %%
from matplotlib.ticker import FuncFormatter
from adjustText import adjust_text

plt.scatter(df_DA_skills_high_demand['skill_percent'], df_DA_skills_high_demand['median_salary'])
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Salary ($USD)')  # Assuming this is the label you want for y-axis
plt.title('Most Optimal Skills for Data Analysts in Germany')

# Get current axes, set limits, and format axes
ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))  # Example formatting y-axis

# Add labels to points and collect them in a list
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], " " + txt))

# Adjust text to avoid overlap and add arrows
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

plt.show()

# %% [markdown]
# Coloring by Technology

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['datarobot',
#   'sap',
#   'visio',
#   'excel',
#   'sas',
#   'power bi',
#   'powerbi',
#   'cognos',
#   'dax',
#   'splunk',
#   'spreadsheet',
#   'sharepoint',
#   'ms access',
#   'sheets',
#   'ssrs',
#   'powerpoint',
#   'microstrategy',
#   'esquisse',
#   'alteryx',
#   'tableau',
#   'qlik',
#   'nuix',
#   'msaccess',
#   'looker',
#   'ssis',
#   'word',
#   'outlook',
#   'spss'],
#  'programming': ['objective-c',
#   'c',
#   'f#',
#   'matlab',
#   'swift',
#   'php',
#   'ruby',
#   'vb.net',
#   'apl',
#   'sql',
#   'nosql',
#   'dart',
#   'css',
#   'ocaml',
#   'sas',
#   'clojure',
#   'r',
#   'visual basic',
#   'typescript',
#   'scala',
#   'mongo',
#   'golang',
#   'elixir',
#   'c#',
#   'visualbasic',
#   'c++',
#   'assembly',
#   'delphi',
#   'haskell',
#   'javascript',
#   'rust',
#   'perl',
#   'shell',
#   'vba',
#   'lisp',
#   'no-sql',
#   't-sql',
#   'groovy',
#   'kotlin',
#   'go',
#   'java',
#   'crystal',
#   'powershell',
#   'pascal',
#   'erlang',
#   'lua',
#   'julia',
#   'cobol',
#   'fortran',
#   'python',
#   'sass',
#   'solidity',
#   'mongodb',
#   'html',
#   'bash'],
#  'cloud': ['azure',
#   'colocation',
#   'snowflake',
#   'databricks',
#   'oracle',
#   'ovh',
#   'aws',
#   'firebase',
#   'aurora',
#   'bigquery',
#   'heroku',
#   'vmware',
#   'watson',
#   'openstack',
#   'linode',
#   'redshift',
#   'ibm cloud',
#   'gcp',
#   'digitalocean'],
#  'libraries': ['chainer',
#   'jupyter',
#   'numpy',
#   'mxnet',
#   'gdpr',
#   'tidyverse',
#   'plotly',
#   'airflow',
#   'matplotlib',
#   'selenium',
#   'react',
#   'pytorch',
#   'pyspark',
#   'tensorflow',
#   'seaborn',
#   'theano',
#   'graphql',
#   'shogun',
#   'xamarin',
#   'mlr',
#   'gtx',
#   'cordova',
#   'rshiny',
#   'hugging face',
#   'ggplot2',
#   'kafka',
#   'electron',
#   'hadoop',
#   'qt',
#   'ionic',
#   'flutter',
#   'mlpack',
#   'huggingface',
#   'spring',
#   'keras',
#   'tidyr',
#   'scikit-learn',
#   'opencv',
#   'spark',
#   'nltk',
#   'pandas',
#   'capacitor',
#   'dplyr',
#   'dlib'],
#  'other': ['chef',
#   'jenkins',
#   'terraform',
#   'svn',
#   'codecommit',
#   'github',
#   'gitlab',
#   'npm',
#   'unity',
#   'ansible',
#   'homebrew',
#   'docker',
#   'kubernetes',
#   'unreal',
#   'atlassian',
#   'flow',
#   'yarn',
#   'bitbucket',
#   'terminal',
#   'puppet',
#   'pulumi',
#   'git'],
#  'databases': ['mysql',
#   'neo4j',
#   'couchbase',
#   'firestore',
#   'elasticsearch',
#   'redis',
#   'sqlite',
#   'mariadb',
#   'postgresql',
#   'cassandra',
#   'dynamodb',
#   'sqlserver',
#   'mongodb',
#   'sql server',
#   'firebase',
#   'db2',
#   'couchdb'],
#  'os': ['windows',
#   'unix',
#   'arch',
#   'redhat',
#   'debian',
#   'fedora',
#   'linux',
#   'suse',
#   'centos',
#   'macos',
#   'wsl',
#   'ubuntu',
#   'kali'],
#  'async': ['smartsheet',
#   'wrike',
#   'airtable',
#   'notion',
#   'workfront',
#   'monday.com',
#   'jira',
#   'planner',
#   'clickup',
#   'confluence',
#   'trello',
#   'dingtalk',
#   'asana',
#   'microsoft lists',
#   'wimi'],
#  'webframeworks': ['jquery',
#   'deno',
#   'ruby',
#   'flask',
#   'asp.net core',
#   'ember.js',
#   'angular.js',
#   'ruby on rails',
#   'asp.netcore',
#   'asp.net',
#   'gatsby',
#   'symfony',
#   'react.js',
#   'django',
#   'node.js',
#   'phoenix',
#   'vue',
#   'fastify',
#   'vue.js',
#   'node',
#   'svelte',
#   'laravel',
#   'play framework',
#   'nuxt.js',
#   'drupal',
#   'express',
#   'rubyon rails',
#   'angular',
#   'blazor',
#   'next.js',
#   'fastapi'],
#  'sync': ['ringcentral',
#   'rocketchat',
#   'unify',
#   'zoom',
#   'webex',
#   'mattermost',
#   'wire',
#   'google chat',
#   'slack',
#   'symphony',
#   'twilio',
#   'microsoft teams']}

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology           skills
# 0   analyst_tools        datarobot
# 0   analyst_tools              sap
# 0   analyst_tools            visio
# 0   analyst_tools            excel
# 0   analyst_tools              sas
# ..            ...              ...
# 9            sync      google chat
# 9            sync            slack
# 9            sync         symphony
# 9            sync           twilio
# 9            sync  microsoft teams
#
# [256 rows x 2 columns]

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#     skill_count  median_salary  skill_percent     technology         skills
# 0            24      101500.00      50.000000    programming            sql
# 1            18      111175.00      37.500000    programming         python
# 2            13      100500.00      27.083333  analyst_tools        tableau
# 3             7      111175.00      14.583333      libraries          spark
# 4             7       75067.50      14.583333    programming              r
# 5             7      105650.00      14.583333  analyst_tools          excel
# 6             5       53014.00      10.416667  analyst_tools         looker
# 7             4       83937.50       8.333333  analyst_tools       power bi
# 8             4       52014.00       8.333333    programming             go
# 9             4      108412.50       8.333333      libraries         pandas
# 10            3      165000.00       6.250000          cloud            gcp
# 11            3      199675.00       6.250000          other         github
# 12            3      100500.00       6.250000          cloud            aws
# 13            3       89100.00       6.250000          cloud          azure
# 14            3      105650.00       6.250000      libraries     matplotlib
# 15            2      105650.00       4.166667      libraries          numpy
# 16            2       82083.75       4.166667    programming             c#
# 17            2      105650.00       4.166667  analyst_tools            sas
# 18            2      105650.00       4.166667    programming            sas
# 19            2       78007.00       4.166667  analyst_tools            sap
# 20            2       83937.50       4.166667  analyst_tools     powerpoint
# 21            1      111175.00       2.083333      libraries        pyspark
# 22            1      102500.00       2.083333          other      atlassian
# 23            1      111175.00       2.083333      libraries          react
# 24            1      166419.50       2.083333          cloud       redshift
# 25            1       89100.00       2.083333      databases     sql server
# 26            1      111175.00       2.083333          other       terminal
# 27            1       57500.00       2.083333  analyst_tools         sheets
# 28            1      111175.00       2.083333    programming         no-sql
# 29            1       92000.00       2.083333    programming         pascal
# 30            1       56700.00       2.083333          cloud         oracle
# 31            1      166419.50       2.083333    programming          nosql
# 32            1       89100.00       2.083333      databases          neo4j
# 33            1      111175.00       2.083333    programming         matlab
# 34            1       89100.00       2.083333             os          linux
# 35            1      166419.50       2.083333      libraries          kafka
# 36            1       89100.00       2.083333    programming          julia
# 37            1      111175.00       2.083333    programming     javascript
# 38            1       75067.50       2.083333    programming           java
# 39            1      105000.00       2.083333          other            git
# 40            1      111175.00       2.083333  webframeworks          flask
# 41            1      111175.00       2.083333      databases  elasticsearch
# 42            1      111175.00       2.083333          cloud     databricks
# 43            1      166419.50       2.083333          cloud       bigquery
# 44            1      166419.50       2.083333          other      terraform

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_limit]
df_DA_skills_tech_high_demand
# Out:
#     skill_count  median_salary  skill_percent     technology      skills
# 0            24       101500.0      50.000000    programming         sql
# 1            18       111175.0      37.500000    programming      python
# 2            13       100500.0      27.083333  analyst_tools     tableau
# 3             7       111175.0      14.583333      libraries       spark
# 4             7        75067.5      14.583333    programming           r
# 5             7       105650.0      14.583333  analyst_tools       excel
# 6             5        53014.0      10.416667  analyst_tools      looker
# 7             4        83937.5       8.333333  analyst_tools    power bi
# 8             4        52014.0       8.333333    programming          go
# 9             4       108412.5       8.333333      libraries      pandas
# 10            3       165000.0       6.250000          cloud         gcp
# 11            3       199675.0       6.250000          other      github
# 12            3       100500.0       6.250000          cloud         aws
# 13            3        89100.0       6.250000          cloud       azure
# 14            3       105650.0       6.250000      libraries  matplotlib

# %% [markdown]
# Plot the results in a scatter plot, coloring the points based on the 'technology' column.

# %%
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in Germany')
plt.legend(title='Technology')


from matplotlib.ticker import FuncFormatter, PercentFormatter

ax = plt.gca()
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))


# Adjust layout and display plot 
plt.tight_layout()
plt.show()
